# %%
# !pip install sqlalchemy 
import pandas as pd
from sqlalchemy import create_engine

# %%
import pymysql
pymysql.install_as_MySQLdb()

# default
engine = create_engine('mysql://root:hello!23@localhost/test_db')

# mysqlclient (a maintained fork of MySQL-Python)
#engine = create_engine('mysql+mysqldb://root:hello!23@localhost/foo')

# PyMySQL
#engine = create_engine('mysql+pymysql://root:hello!23@localhost/foo')

# %%
sql = """
SELECT *
FROM adnimerge
"""
df = pd.read_sql_query(sql, engine)
df.head()
# Out:
#    RID        PTID VISCODE  SITE COLPROT ORIGPROT    EXAMDATE DX_bl   AGE  \
# 0    2  011_S_0002      bl    11   ADNI1    ADNI1  2005-09-08    CN  74.3
# 1    3  011_S_0003      bl    11   ADNI1    ADNI1  2005-09-12    AD  81.3
# 2    3  011_S_0003     m06    11   ADNI1    ADNI1  2006-03-13    AD  81.3
# 3    3  011_S_0003     m12    11   ADNI1    ADNI1  2006-09-12    AD  81.3
# 4    3  011_S_0003     m24    11   ADNI1    ADNI1  2007-09-12    AD  81.3
#
#   PTGENDER  ...  TAU_bl PTAU_bl   FDG_bl PIB_bl  AV45_bl  Years_bl  Month_bl  \
# 0     Male  ...                  1.36665                  0.000000   0.00000
# 1     Male  ...   239.7   22.83  1.08355                  0.000000   0.00000
# 2     Male  ...   239.7   22.83  1.08355                  0.498289   5.96721
# 3     Male  ...   239.7   22.83  1.08355                  0.999316  11.96720
# 4     Male  ...   239.7   22.83  1.08355                  1.998630  23.93440
#
#   Month   M           update_stamp
# ...

# %%
sql = """
SELECT *
FROM pima_indians_diabetes
"""
df = pd.read_sql_query(sql, engine)
df.head()
# Out:
#    # 1                           Number of times pregnant
# 0  # 1                           Number of times pregnant
# 1  # 2  Plasma glucose concentration a 2 hours in an o...
# 2  # 3                   Diastolic blood pressure (mm Hg)
# 3  # 4                   Triceps skin fold thickness (mm)
# 4  # 5                     2-Hour serum insulin (mu U/ml)

# %%
sql = """
SELECT PTID, COLPROT, PTAU_bl
FROM adnimerge
"""
df = pd.read_sql_query(sql, engine)
df.head()
# Out:
#          PTID COLPROT PTAU_bl
# 0  011_S_0002   ADNI1
# 1  011_S_0003   ADNI1   22.83
# 2  011_S_0003   ADNI1   22.83
# 3  011_S_0003   ADNI1   22.83
# 4  011_S_0003   ADNI1   22.83

# %%
sql = """
SELECT *
FROM test_table1
"""
df = pd.read_sql_query(sql, engine)
df.head()
# Out:
#    roll       name
# 0     1   xiaoming
# 1     2  xiaoming2

# %%
scriptFile = open("test_sql.sql",'r')
script = scriptFile.read()
df = pd.read_sql_query(script, engine)
df.head()
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1243                     self.dialect.do_execute(
# -> 1244                         cursor, statement, parameters, context
#    1245                     )
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     549     def do_execute(self, cursor, statement, parameters, context=None):
# --> 550         cursor.execute(statement, parameters)
#     551
#
# ~/anaconda3/lib/python3.7/site-packages/pymysql/cursors.py in execute(self, query, args)
#     147
# --> 148         result = self._query(query)
#     149         self._executed = query
#
# ...
